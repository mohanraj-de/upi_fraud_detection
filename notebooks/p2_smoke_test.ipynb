# %%
from pyspark.sql import SparkSession

spark=(SparkSession.Builder().
    config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.0,org.postgresql:postgresql:42.7.3,io.delta:delta-spark_2.12:3.2.0").
    config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .getOrCreate()
)

# %%
df=spark.read.format('delta').load('/home/jovyan/lakehouse/bronze/upi_raw')
df.count()
# Out:
# 3297

# %%
df=spark.read.format('delta').load('/home/jovyan/lakehouse/bronze/upi_raw')
df.count()
# Out:
# 3360

# %%
# post crash restart
df.count()
# Out:
# 4673

# %%
df.groupBy("txn_id").count().filter("count > 1").show()
# no duplicates - acceptance criteria passed
# Out:
# +------+-----+
# |txn_id|count|
# +------+-----+
# +------+-----+
