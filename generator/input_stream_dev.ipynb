# %%
i=2
a=f"user{i:04d}"
print(a)
# Out:
# user0002

# %%
import random
from dataclasses import dataclass, field

BANK_HANDLES = ["oksbi", "okhdfcbank", "okicici", "okaxis", "ybl", "paytm", "okbizaxis"]
INDIAN_STATES = [
    "Maharashtra", "Karnataka", "Delhi", "Tamil Nadu", "West Bengal",
    "Gujarat", "Uttar Pradesh", "Telangana", "Rajasthan", "Kerala",
    "Punjab", "Haryana", "Madhya Pradesh", "Bihar", "Odisha",
]

# @dataclass is a decorator from Python's standard library (dataclasses module) that auto-generates boilerplate for classes that just hold data — __init__, __repr__, and __eq__ — based on the fields you declare.

@dataclass
class User:
    user_id: str
    upi: str
    state: str
    devices: list = field(default_factory=list)
    typical_spend: float = 500.0

def build_users(n: int) -> list:
    users = []
    for i in range(n):
        bank = random.choice(BANK_HANDLES)
        num_devices = random.randint(1, 3)
        users.append(User(
            user_id=f"user{i:04d}",
            upi=f"user{i:04d}@{bank}",
            state=random.choice(INDIAN_STATES),
            devices=[f"user{i:04d}_{j}" for j in range(num_devices)],
            typical_spend=round(random.lognormvariate(6.2, 0.7), 2),  # right-skewed spend per user, median ~e^6.2≈490
        ))
    return users

a=build_users(100)
print("sample")
for i in a[:5]:
    print(i)
# Out:
# sample
# User(user_id='user0000', upi='user0000@okicici', state='Kerala', devices=['user0000_0'], typical_spend=470.73)
# User(user_id='user0001', upi='user0001@oksbi', state='Gujarat', devices=['user0001_0', 'user0001_1', 'user0001_2'], typical_spend=1178.83)
# User(user_id='user0002', upi='user0002@okbizaxis', state='Telangana', devices=['user0002_0', 'user0002_1'], typical_spend=320.92)
# User(user_id='user0003', upi='user0003@paytm', state='Maharashtra', devices=['user0003_0', 'user0003_1'], typical_spend=419.99)
# User(user_id='user0004', upi='user0004@okaxis', state='Telangana', devices=['user0004_0', 'user0004_1', 'user0004_2'], typical_spend=631.76)

# %%
MERCHANT_CATEGORIES = [
    "grocery", "food_delivery", "fuel", "travel", "entertainment",
    "utilities", "ecommerce", "healthcare", "education", "electronics",
    "fashion", "pharmacy",
]

@dataclass
class Merchant:
    merchant_id: str
    upi: str
    category: str

def build_merchants(n: int) -> list:
    merchants = []
    for i in range(n):
        bank = random.choice(BANK_HANDLES)
        merchants.append(Merchant(
            merchant_id=f"merchant{i:03d}",
            upi=f"merchant{i:03d}@{bank}",
            category=random.choice(MERCHANT_CATEGORIES),
        ))
    return merchants

b=build_merchants(20)
print("sample")
for i in b[:5]:
    print(i)
# Out:
# sample
# Merchant(merchant_id='merchant000', upi='merchant000@oksbi', category='pharmacy')
# Merchant(merchant_id='merchant001', upi='merchant001@paytm', category='entertainment')
# Merchant(merchant_id='merchant002', upi='merchant002@ybl', category='fuel')
# Merchant(merchant_id='merchant003', upi='merchant003@ybl', category='food_delivery')
# Merchant(merchant_id='merchant004', upi='merchant004@okbizaxis', category='fashion')

# %%
random.seed(42)
user=build_users(20)
merchant=build_merchants(5)

reciever=random.choice(merchant)

def select_receiver(sender,user,merchant):
    ## 60% merchants and 40% person 2 person
    if random.random() <0.6:
        m=random.choice(merchant)
        return m.merchant_id,"P2M",m.category
    u=random.choice(user)
    while sender.upi==u.upi:
        u=random.choice(user)
    return u.upi,"P2P",None

for i in range(5):
    sender=random.choice(user)
    receiver_upi,payment_segment,receiver_category=select_receiver(sender,user,merchant)
    print(f"mode: {i}")
    print("sender details: " ,sender.user_id, " | ",sender.upi," | ",sender.state," | ",sender.typical_spend,random.choice(sender.devices))
    print("receiver details: " ,receiver_upi, " | ",payment_segment," | ",receiver_category)
# Out:
# mode: 0
# sender details:  user0019  |  user0019@ybl  |  Gujarat  |  498.99 user0019_1
# receiver details:  user0016@ybl  |  P2P  |  None
# mode: 1
# sender details:  user0017  |  user0017@paytm  |  Delhi  |  338.74 user0017_0
# receiver details:  user0000@paytm  |  P2P  |  None
# mode: 2
# sender details:  user0017  |  user0017@paytm  |  Delhi  |  338.74 user0017_0
# receiver details:  user0010@oksbi  |  P2P  |  None
# mode: 3
# sender details:  user0009  |  user0009@okbizaxis  |  Kerala  |  1156.75 user0009_0
# receiver details:  merchant003  |  P2M  |  electronics
# mode: 4
# sender details:  user0008  |  user0008@okaxis  |  Rajasthan  |  252.45 user0008_0
# receiver details:  user0005@okaxis  |  P2P  |  None

# %%
fraud_rate=0.2

n=10
f=int(n*fraud_rate)
nf=n-f

import uuid
from datetime import datetime,timezone

def make_event(sender, receiver_upi, receiver_type, receiver_category,
               amount, device_id, status, is_fraud=False, fraud_pattern=None,
               timestamp=None) -> dict:
    ts = datetime.now(timezone.utc)
    return {
        "txn_id": str(uuid.uuid4()),
        "timestamp": ts.isoformat(timespec="seconds").replace("+00:00", "Z"),
        "sender_upi": sender.upi,
        "sender_state": sender.state,
        "sender_device_id": device_id,
        "receiver_upi": receiver_upi,
        "receiver_type": receiver_type,
        "receiver_category": receiver_category,
        "amount": round(amount, 2),
        "status": status,
        "is_fraud": is_fraud,
        "fraud_pattern": fraud_pattern,
    }

op=[]
for i in range(nf):
    sender=random.choice(user)
    receiver_upi,payment_segment,receiver_category=select_receiver(sender,user,merchant)
    op.append(make_event(sender,receiver_upi,payment_segment,receiver_category,sender.typical_spend,"SUCCESS","N",""))

# fraud event
for i in range(f):
    sender=random.choice(user)
    receiver_upi,payment_segment,receiver_category=select_receiver(sender,user,merchant)
    amt=round(random.randint(10000,100000),2)
    op.append(make_event(sender,receiver_upi,payment_segment,receiver_category,amt,"SUCCESS","Y","high_spend"))

op
# Out:
# [{'txn_id': 'a5363395-8e4e-49fb-8771-0bf2a256143b',
#   'timestamp': '2026-07-22T16:40:01Z',
#   'sender_upi': 'user0001@okhdfcbank',
#   'sender_state': 'Karnataka',
#   'sender_device_id': 'SUCCESS',
#   'receiver_upi': 'user0003@ybl',
#   'receiver_type': 'P2P',
#   'receiver_category': None,
#   'amount': 3526.36,
#   'status': 'N',
#   'is_fraud': '',
#   'fraud_pattern': None},
#  {'txn_id': 'bab539bd-893b-4832-b4cd-5a4c4cf3bf1c',
#   'timestamp': '2026-07-22T16:40:01Z',
#   'sender_upi': 'user0001@okhdfcbank',
#   'sender_state': 'Karnataka',
#   'sender_device_id': 'SUCCESS',
#   'receiver_upi': 'merchant002',
#   'receiver_type': 'P2M',
#   'receiver_category': 'fashion',
#   'amount': 3526.36,
#   'status': 'N',
#   'is_fraud': '',
#   'fraud_pattern': None},
#  {'txn_id': 'd5f68e48-8d6a-45c8-ad19-910015595776',
#   'timestamp': '2026-07-22T16:40:01Z',
#   'sender_upi': 'user0003@ybl',
#   'sender_state': 'Haryana',
#   'sender_device_id': 'SUCCESS',
#   'receiver_upi': 'merchant001',
#   'receiver_type': 'P2M',
#   'receiver_category': 'fashion',
#   'amount': 731.82,
#   'status': 'N',
#   'is_fraud': '',
#   'fraud_pattern': None},
#  {'txn_id': '84695875-27be-4213-a743-20a8c39c9118',
#   'timestamp': '2026-07-22T16:40:01Z',
#   'sender_upi': 'user0017@paytm',
#   'sender_state': 'Delhi',
#   'sender_device_id': 'SUCCESS',
#   'receiver_upi': 'merchant003',
#   'receiver_type': 'P2M',
#   'receiver_category': 'electronics',
#   'amount': 338.74,
#   'status': 'N',
#   'is_fraud': '',
#   'fraud_pattern': None},
#  {'txn_id': '2b988d2e-8aeb-4f94-8a92-a662a56913c3',
#   'timestamp': '2026-07-22T16:40:01Z',
#   'sender_upi': 'user0005@okaxis',
#   'sender_state': 'West Bengal',
#   'sender_device_id': 'SUCCESS',
#   'receiver_upi': 'merchant001',
#   'receiver_type': 'P2M',
#   'receiver_category': 'fashion',
#   'amount': 396.91,
#   'status': 'N',
#   'is_fraud': '',
#   'fraud_pattern': None},
#  {'txn_id': '820005e3-6170-408f-b2e4-78a37b9b0560',
#   'timestamp': '2026-07-22T16:40:01Z',
#   'sender_upi': 'user0002@oksbi',
#   'sender_state': 'Uttar Pradesh',
#   'sender_device_id': 'SUCCESS',
#   'receiver_upi': 'merchant004',
#   'receiver_type': 'P2M',
#   'receiver_category': 'ecommerce',
#   'amount': 219.93,
#   'status': 'N',
#   'is_fraud': '',
#   'fraud_pattern': None},
#  {'txn_id': '6a73e73b-649e-4e99-812f-c0366296d30c',
#   'timestamp': '2026-07-22T16:40:01Z',
#   'sender_upi': 'user0003@ybl',
#   'sender_state': 'Haryana',
#   'sender_device_id': 'SUCCESS',
#   'receiver_upi': 'merchant004',
#   'receiver_type': 'P2M',
#   'receiver_category': 'ecommerce',
#   'amount': 731.82,
#   'status': 'N',
#   'is_fraud': '',
#   'fraud_pattern': None},
#  {'txn_id': '1fe15779-b416-464a-84e1-39afd03c1ba6',
#   'timestamp': '2026-07-22T16:40:01Z',
#   'sender_upi': 'user0000@paytm',
#   'sender_state': 'Maharashtra',
#   'sender_device_id': 'SUCCESS',
#   'receiver_upi': 'user0007@oksbi',
#   'receiver_type': 'P2P',
#   'receiver_category': None,
#   'amount': 723.53,
#   'status': 'N',
#   'is_fraud': '',
#   'fraud_pattern': None},
#  {'txn_id': '2f422714-92a9-42f0-9f41-668239a70d3b',
#   'timestamp': '2026-07-22T16:40:01Z',
#   'sender_upi': 'user0005@okaxis',
#   'sender_state': 'West Bengal',
#   'sender_device_id': 'SUCCESS',
#   'receiver_upi': 'merchant003',
#   'receiver_type': 'P2M',
#   'receiver_category': 'electronics',
#   'amount': 38016,
#   'status': 'Y',
#   'is_fraud': 'high_spend',
#   'fraud_pattern': None},
#  {'txn_id': '34734308-6a27-4862-8af2-bea052b61a8d',
#   'timestamp': '2026-07-22T16:40:01Z',
#   'sender_upi': 'user0012@okicici',
#   'sender_state': 'Odisha',
#   'sender_device_id': 'SUCCESS',
#   'receiver_upi': 'user0005@okaxis',
#   'receiver_type': 'P2P',
#   'receiver_category': None,
#   'amount': 59672,
#   'status': 'Y',
#   'is_fraud': 'high_spend',
#   'fraud_pattern': None}]

# %%
x=[]

def high_spend(users, merchants):
    sender=random.choice(users)
    receiver_upi,payment_segment,receiver_category=select_receiver(sender,user,merchants)
    amt=round(random.randint(10000,100000),2)    
    return make_event(sender,receiver_upi,payment_segment,receiver_category,amt,"SUCCESS","Y","high_spend")


def odd_hours(users, merchants):
    sender=random.choice(users)
    receiver_upi,payment_segment,receiver_category=select_receiver(sender,users,merchants)
    odd_hour_ts = datetime.now(timezone.utc).replace(
        hour=random.randint(1, 4), minute=random.randint(0, 59), second=random.randint(0, 59),
    )
    amt=sender.typical_spend*random.uniform(8,10)
    return make_event(sender,receiver_upi,payment_segment,receiver_category,amt,"SUCCESS","Y","odd_hours",timestamp=odd_hour_ts)

def legit_txn(users, merchants):
    sender=random.choice(users)
    receiver_upi,payment_segment,receiver_category=select_receiver(sender,user,merchants)
    return make_event(sender,receiver_upi,payment_segment,receiver_category,sender.typical_spend,"SUCCESS","N","")

# %%
n=30
fraud_rate=0.5
f=int(n*fraud_rate)
nf=round(n-f)

txn=[]
for _ in range(nf):
    txn.append(legit_txn(user,merchant))

frd=0
n_frd=0
while frd+n_frd<n:
    if frd<n:
        generator=random.choice([legit_txn,odd_hours,high_spend])
        
        if generator==rapid_burst or generator==odd_hours:
            frd+=1
            txn.append(generator(user,merchant))
        else:
            txn.append(generator(user,merchant))
            n_frd+=1

        continue
    else:
        txn.append(high_spend(user,merchant))
        n_frd+=1

    

import pandas as pd

df=pd.DataFrame(txn)

# %%
df
# Out:
#                                   txn_id             timestamp  \
# 0   d16c232d-3bb7-4165-822f-5c09e87bd478  2026-07-22T18:01:11Z
# 1   4202a6e9-96cb-4bd6-a03e-eab11e1afd68  2026-07-22T18:01:11Z
# 2   c0c0e2ed-88fe-4105-abff-b5c9a8d0111c  2026-07-22T18:01:11Z
# 3   e52a207c-7dd1-4863-b562-156e5452c13a  2026-07-22T18:01:11Z
# 4   dafd43c9-2063-4a81-bf6e-3a8d9b8e7e7c  2026-07-22T18:01:11Z
# 5   4fcff1ac-f3d4-4eb8-a7d4-04f14621c900  2026-07-22T18:01:11Z
# 6   36472de6-fc9a-4b0a-9f91-4f4ef0d065bc  2026-07-22T18:01:11Z
# 7   d2a30608-c8b7-42c4-8ece-93afaffe34d8  2026-07-22T18:01:11Z
# 8   3436f58b-5fd5-4388-9e13-5778fcfffa1e  2026-07-22T18:01:11Z
# 9   b7558deb-2a6e-446d-9f1d-b2fe9fae0a91  2026-07-22T18:01:11Z
# 10  2cae5b0b-d7ca-449a-a083-d2e443a977a5  2026-07-22T18:01:11Z
# 11  964a1847-bad0-4113-aa46-e887b03ba350  2026-07-22T18:01:11Z
# 12  cc9f8b4c-25e2-4468-a1d7-97d2b1dcc1b6  2026-07-22T18:01:11Z
# 13  122ba051-4733-42a1-ace6-1a33a646fa35  2026-07-22T18:01:11Z
# 14  ed171715-3b4b-41d7-ae8e-9b4d4c81b5bc  2026-07-22T18:01:11Z
# 15  33a55acc-649c-483d-b051-73bfd61beeba  2026-07-22T18:01:11Z
# 16  cc6f7796-763f-460a-9998-c2e844cf3fa7  2026-07-22T18:01:11Z
# 17  46198364-293b-4975-a904-69493591f392  2026-07-22T18:01:11Z
# 18  87cf6aba-0422-420b-a018-2c316564af7d  2026-07-22T18:01:11Z
# 19  7ac5d4fb-43e6-4c55-9656-0e64326a7219  2026-07-22T18:01:11Z
# 20  bc613f55-5a15-43c3-bebe-007a77fe5a90  2026-07-22T18:01:11Z
# 21  3387d1e4-f0e1-462a-991b-7b8a9f05b865  2026-07-22T18:01:11Z
# 22  eb65f22a-7f53-4824-8907-d48336152cf8  2026-07-22T18:01:11Z
# 23  6ba591bf-4a8d-4e02-a795-db051f60471f  2026-07-22T18:01:11Z
# 24  aca3072e-e26f-4767-9298-68be4c456a2d  2026-07-22T18:01:11Z
# 25  e8e932ff-92e2-4f56-bcc3-f838f06a0927  2026-07-22T18:01:11Z
# 26  8c5a961d-221b-4b6b-af98-017175d1b85c  2026-07-22T18:01:11Z
# 27  ac15996d-b2b9-4c2a-98c1-fa46ee33d319  2026-07-22T18:01:11Z
# 28  46ac9202-2dc4-48ef-a956-a14431a82080  2026-07-22T18:01:11Z
# 29  95314d4d-d12c-42c7-b321-a460268fb99c  2026-07-22T18:01:11Z
# 30  3b9c5311-5010-4d89-8e40-7ba8ece652c6  2026-07-22T18:01:11Z
# 31  102b5df5-337d-454f-91b2-c5d983c9bef6  2026-07-22T18:01:11Z
# 32  9c907701-6e5d-42f0-aebb-ce1db10671dc  2026-07-22T18:01:11Z
# 33  bd97c8b2-bb12-4c09-9f24-94aaf11fec9d  2026-07-22T18:01:11Z
# 34  ded87dff-fcde-4804-8104-c175e9120a4b  2026-07-22T18:01:11Z
# 35  3a0802fc-b271-4bb6-850d-d529577462c8  2026-07-22T18:01:11Z
# 36  887238d9-44ef-4f69-a92a-54dd3e293e39  2026-07-22T18:01:11Z
# 37  20e20ae8-9b8a-476d-9f50-b996ff5affde  2026-07-22T18:01:11Z
# 38  f7dc7fe4-0a28-4a27-a01c-7eb052eb12ed  2026-07-22T18:01:11Z
# 39  5a6b25e7-e94c-4788-9b2b-3d031db83c75  2026-07-22T18:01:11Z
# 40  6b3c52f2-f9d8-4c26-951b-ea87311441fa  2026-07-22T18:01:11Z
# 41  eddc84fa-7cbe-47e7-99b4-d66f77910550  2026-07-22T18:01:11Z
# 42  ed18f036-a3e4-424c-8eb8-937357b09824  2026-07-22T18:01:11Z
# 43  2733a366-5f7c-4ec0-a8d2-b0c0bf280f98  2026-07-22T18:01:11Z
# 44  956565c2-1734-445e-8d68-319d2d111588  2026-07-22T18:01:11Z
#
#              sender_upi sender_state sender_device_id         receiver_upi  \
# 0          user0003@ybl      Haryana          SUCCESS          merchant001
# 1        user0010@oksbi        Bihar          SUCCESS       user0015@paytm
# 2       user0014@okaxis       Odisha          SUCCESS          merchant003
# 3        user0013@paytm    Rajasthan          SUCCESS          merchant000
# 4          user0019@ybl      Gujarat          SUCCESS      user0014@okaxis
# 5        user0013@paytm    Rajasthan          SUCCESS       user0017@paytm
# 6        user0015@paytm        Bihar          SUCCESS          merchant004
# 7        user0000@paytm  Maharashtra          SUCCESS       user0015@paytm
# 8        user0000@paytm  Maharashtra          SUCCESS          merchant002
# 9        user0000@paytm  Maharashtra          SUCCESS  user0004@okhdfcbank
# 10         user0003@ybl      Haryana          SUCCESS       user0015@paytm
# 11         user0019@ybl      Gujarat          SUCCESS       user0000@paytm
# 12         user0019@ybl      Gujarat          SUCCESS          merchant002
# 13   user0009@okbizaxis       Kerala          SUCCESS          merchant000
# 14         user0018@ybl  West Bengal          SUCCESS       user0015@paytm
# 15       user0013@paytm    Rajasthan          SUCCESS          merchant002
# 16       user0007@oksbi    Telangana          SUCCESS          merchant004
# 17      user0008@okaxis    Rajasthan          SUCCESS          merchant004
# 18   user0009@okbizaxis       Kerala          SUCCESS          merchant000
# 19      user0005@okaxis  West Bengal          SUCCESS          merchant002
# 20  user0001@okhdfcbank    Karnataka          SUCCESS          merchant000
# 21       user0017@paytm        Delhi          SUCCESS         user0003@ybl
# 22         user0003@ybl      Haryana          SUCCESS   user0009@okbizaxis
# 23  user0001@okhdfcbank    Karnataka          SUCCESS         user0003@ybl
# 24         user0016@ybl      Gujarat          SUCCESS         user0003@ybl
# 25       user0015@paytm        Bihar          SUCCESS          merchant001
# 26         user0018@ybl  West Bengal          SUCCESS          merchant003
# 27         user0018@ybl  West Bengal          SUCCESS       user0013@paytm
# 28         user0018@ybl  West Bengal          SUCCESS          merchant001
# 29     user0012@okicici       Odisha          SUCCESS  user0001@okhdfcbank
# 30   user0009@okbizaxis       Kerala          SUCCESS         user0019@ybl
# 31      user0005@okaxis  West Bengal          SUCCESS  user0004@okhdfcbank
# 32         user0019@ybl      Gujarat          SUCCESS       user0015@paytm
# 33       user0000@paytm  Maharashtra          SUCCESS          merchant004
# 34     user0012@okicici       Odisha          SUCCESS      user0005@okaxis
# 35  user0004@okhdfcbank       Kerala          SUCCESS  user0001@okhdfcbank
# 36  user0004@okhdfcbank       Kerala          SUCCESS       user0013@paytm
# 37   user0009@okbizaxis       Kerala          SUCCESS          merchant002
# 38         user0019@ybl      Gujarat          SUCCESS       user0011@paytm
# 39  user0001@okhdfcbank    Karnataka          SUCCESS         user0016@ybl
# 40         user0019@ybl      Gujarat          SUCCESS          merchant002
# 41       user0007@oksbi    Telangana          SUCCESS       user0010@oksbi
# 42       user0000@paytm  Maharashtra          SUCCESS       user0006@oksbi
# 43       user0000@paytm  Maharashtra          SUCCESS         user0016@ybl
# 44         user0016@ybl      Gujarat          SUCCESS          merchant000
#
#    receiver_type receiver_category    amount status    is_fraud fraud_pattern
# 0            P2M           fashion    731.82      N                      None
# 1            P2P              None    253.76      N                      None
# 2            P2M       electronics    720.15      N                      None
# 3            P2M     food_delivery    684.64      N                      None
# 4            P2P              None    498.99      N                      None
# 5            P2P              None    684.64      N                      None
# 6            P2M         ecommerce    433.94      N                      None
# 7            P2P              None    723.53      N                      None
# 8            P2M           fashion    723.53      N                      None
# 9            P2P              None    723.53      N                      None
# 10           P2P              None    731.82      N                      None
# 11           P2P              None    498.99      N                      None
# 12           P2M           fashion    498.99      N                      None
# 13           P2M     food_delivery   1156.75      N                      None
# 14           P2P              None    827.97      N                      None
# 15           P2M           fashion  57080.00      Y  high_spend          None
# 16           P2M         ecommerce   2485.53      N                      None
# 17           P2M         ecommerce   2334.99      Y   odd_hours          None
# 18           P2M     food_delivery  78307.00      Y  high_spend          None
# 19           P2M           fashion   3538.13      Y   odd_hours          None
# 20           P2M     food_delivery  29719.87      Y   odd_hours          None
# 21           P2P              None   3090.11      Y   odd_hours          None
# 22           P2P              None  96536.00      Y  high_spend          None
# 23           P2P              None   3526.36      N                      None
# 24           P2P              None   1982.38      Y   odd_hours          None
# 25           P2M           fashion    433.94      N                      None
# 26           P2M       electronics    827.97      N                      None
# 27           P2P              None   8179.73      Y   odd_hours          None
# 28           P2M           fashion    827.97      N                      None
# 29           P2P              None    624.76      N                      None
# 30           P2P              None   9257.87      Y   odd_hours          None
# 31           P2P              None  93523.00      Y  high_spend          None
# 32           P2P              None  67712.00      Y  high_spend          None
# 33           P2M         ecommerce    723.53      N                      None
# 34           P2P              None    624.76      N                      None
# 35           P2P              None  51002.00      Y  high_spend          None
# 36           P2P              None    713.26      N                      None
# 37           P2M           fashion  10769.73      Y   odd_hours          None
# 38           P2P              None   4778.19      Y   odd_hours          None
# 39           P2P              None  32279.39      Y   odd_hours          None
# 40           P2M           fashion    498.99      N                      None
# 41           P2P              None  20629.62      Y   odd_hours          None
# 42           P2P              None    723.53      N                      None
# 43           P2P              None   6766.73      Y   odd_hours          None
# 44           P2M     food_delivery  51572.00      Y  high_spend          None

# %%
## version 2 fraud samples



n=30
fraud_rate=0.5
f=int(n*fraud_rate)
nf=round(n-f)

def rapid_burst(users, merchants,rb) -> list:
    sender=random.choice(users)
    receiver_upi,payment_segment,receiver_category=select_receiver(sender,users,merchants)
    
    amt=random.randint(1000,10000)
    rapid_op=[]
    for _ in range(rb):
        rapid_op.append(make_event(sender,receiver_upi,payment_segment,receiver_category,amt,"SUCCESS","Y","rapid_burst"))

    return rapid_op

txn=[]
for _ in range(nf):
    txn.append(legit_txn(user,merchant))

cnt=f
while cnt<n:
    rb=random.randint(3,5)
    if rb>n-cnt:
        generator=random.choice([rapid_burst,high_spend])
        
        if generator==rapid_burst:
            cnt+=rb
            txn.extend(generator(user,merchant,rb))
        else:
            txn.append(high_spend(user,merchant))
            cnt+=1

        continue
    else:
        txn.append(high_spend(user,merchant))
        cnt+=1

    

txn

# %%
while cnt<n:
    generator=random.choice(choices)
    if txn=="rapid_burst":
        rb=random.randint(5,10)
        if rb>n-cnt:
            continue
        rapid_burst(users, merchants,rb)
# Out:
# 'merchant002'

# %%
print(make_event(sender,reciever.merchant_id,"P2P",reciever.category,sender.typical_spend,random.choice(sender.devices),"success"))
# Out:
# {'txn_id': 'cf440877-0cf0-4e1e-b609-2698d0054b23', 'timestamp': '2026-07-22T14:03:32Z', 'sender_upi': 'user0012@okicici', 'sender_state': 'Odisha', 'sender_device_id': 'user0012_2', 'receiver_upi': 'merchant004', 'receiver_type': 'P2P', 'receiver_category': 'ecommerce', 'amount': 624.76, 'status': 'success', 'is_fraud': False, 'fraud_pattern': None}

# %%
def pick_receiver(sender, users, merchants):
    """60% P2M / 40% P2P, matching legitimate traffic mix."""
    if random.random() < 0.6:
        merchant = random.choice(merchants)
        return merchant.upi, "P2M", merchant.category
    other = random.choice(users)
    while other.user_id == sender.user_id:
        other = random.choice(users)
    return other.upi, "P2P", None

# %%
STATUS_CHOICES = ["SUCCESS", "FAILED", "REVERSED"]
STATUS_WEIGHTS = [0.95, 0.04, 0.01]

random.choices(STATUS_CHOICES, weights=STATUS_WEIGHTS, k=1)[0]
# Out:
# 'SUCCESS'
